# %%
import numpy as np

def f(t,x,n):
    return np.cos(n*t-x*np.sin(t))

def IntegralPorSimpson(a,b,nsteps,x,n):
	nsteps*=2
	h=(b-a)/nsteps
	suma=0
	for i in range(nsteps+1):
		t=a+i*h
		if(i==0 or i==nsteps):
  			suma+=f(t,x,n)
		elif(i%2==0):
			suma+=2*f(t,x,n)
		else:
			suma+=4*f(t,x,n)
	return suma*h/3

# %%
def Bessel(n,x):
    return (1/np.pi)*IntegralPorSimpson(0,np.pi,100,x,n)

# %%
import matplotlib.pyplot as plt

n=3
a=0
b=10
Nsteps=100
dx=(b-a)/Nsteps
xdata = np.zeros(Nsteps)
ydata = np.zeros(Nsteps)
for i in range(Nsteps):
    x=a+i*dx
    xdata[i]=x
    ydata[i]=Bessel(n,x)

plt.plot(xdata,ydata)
plt.show()

# %%
# %%writefile Simpson.cpp
# #include <iostream>
# #include <cmath>
# #include <vector>
#
# double f(double t, double x, int n) {
#     return cos(n * t - x * sin(t));
# }
#
# double IntegralPorSimpson(double a, double b, int nsteps, double x, int n) {
#     nsteps *= 2;
#     double h = (b - a) / nsteps;
#     double suma = 0;
#
#     for (int i = 0; i <= nsteps; ++i) {
#         double t = a + i * h;
#         if (i == 0 || i == nsteps) {
#             suma += f(t, x, n);
#         } else if (i % 2 == 0) {
#             suma += 2 * f(t, x, n);
#         } else {
#             suma += 4 * f(t, x, n);
#         }
#     }
#
#     return suma * h / 3;
# }
#
# double Bessel(int n, double x) {
#     return (1 / M_PI) * IntegralPorSimpson(0, M_PI, 100, x, n);
# }
#
# int main() {
#     int n = 3;
#     double a = 0;
#     double b = 10;
#     int Nsteps = 100;
#     double dx = (b - a) / Nsteps;
#
#     std::vector<double> xdata(Nsteps);
#     std::vector<double> ydata(Nsteps);
#
#     for (int i = 0; i < Nsteps; ++i) {
#         double x = a + i * dx;
#         xdata[i] = x;
#         ydata[i] = Bessel(n, x);
#     }
#
#     for (int i = 0; i < Nsteps; ++i) {
#         std::cout << xdata[i] << "\t" << ydata[i] << std::endl;
#     }
#
#     return 0;
# }
# Out:
# Overwriting Simpson.cpp

# %%
# %%cmd
# g++ Simpson.cpp -o Simpson.exe
# dir
# Out:
# Microsoft Windows [Versión 10.0.19045.4046]
# (c) Microsoft Corporation. Todos los derechos reservados.
#
# (base) d:\Personal\Estudio\Universidad\Matriculas\Octava matricula\Métodos de Simulación\Clases\Programación Básica (repaso) y Ec. Dif. Ordinarias (3 clases)>g++ Simpson.cpp -o Simpson.exe
# (base) d:\Personal\Estudio\Universidad\Matriculas\Octava matricula\Métodos de Simulación\Clases\Programación Básica (repaso) y Ec. Dif. Ordinarias (3 clases)>dir
#  El volumen de la unidad D es HDD
#  El número de serie del volumen es: D6C3-61B1
#
#  Directorio de d:\Personal\Estudio\Universidad\Matriculas\Octava matricula\Métodos de Simulación\Clases\Programación Básica (repaso) y Ec. Dif. Ordinarias (3 clases)
#
# 20/02/2024  21:55    <DIR>          .
# 20/02/2024  21:55    <DIR>          ..
# 17/02/2024  22:50             1.346 (Feb07) Primeros_programas_y_familiarización_con_los_entornos_de_trabajo.cpp
# 17/02/2024  23:12             7.962 (Feb07) Primeros_programas_y_familiarización_con_los_entornos_de_trabajo.ipynb
# 20/02/2024  21:14            46.065 (Feb09) Integración_numérica_de_ecuaciones_ordinarias.ipynb
# 17/02/2024  23:12            15.566 (Feb14) Cuadratura_de_Gauss.ipynb
# 17/02/2024  09:35            40.052 (Feb16) Euler y Runge-Kutta para una ecuación de primer orden.ipynb
# 18/02/2024  12:09             2.336 Cuadratura_de_Gauss_2024_I_en_Python.ipynb
# 20/02/2024  21:26             1.449 data.cat
# 20/02/2024  21:11                 0 data.dat
# 20/02/2024  21:25                 0 data.txt
# 20/02/2024  21:26             1.449 datos.cat
# 20/02/2024  21:28             1.449 datos.txt
# 18/02/2024  12:08             1.199 program.cpp
# 20/02/2024  21:55             1.200 Simpson.cpp
# 20/02/2024  21:55            74.551 Simpson.exe
# 20/02/2024  21:21            74.551 Simpson.out
# 17/02/2024  22:48           176.546 Taller 1, Ejercicio 2 Runge-Kutta y Lanzadera Modos de Oscilación..ipynb
#               16 archivos        445.721 bytes
#                2 dirs  123.200.425.984 bytes libres
#
# (base) d:\Personal\Estudio\Universidad\Matriculas\Octava matricula\Métodos de Simulación\Clases\Programación Básica (repaso) y Ec. Dif. Ordinarias (3 clases)>

# %%
# %%cmd
# Simpson.exe
# Out:
# Microsoft Windows [Versión 10.0.19045.4046]
# (c) Microsoft Corporation. Todos los derechos reservados.
#
# (base) d:\Personal\Estudio\Universidad\Matriculas\Octava matricula\Métodos de Simulación\Clases\Programación Básica (repaso) y Ec. Dif. Ordinarias (3 clases)>Simpson.exe
# 0	-2.44249e-17
# 0.1	2.08203e-05
# 0.2	0.00016625
# 0.3	0.000559343
# 0.4	0.00132005
# 0.5	0.00256373
# 0.6	0.00439966
# 0.7	0.00692965
# 0.8	0.0102468
# 0.9	0.014434
# 1	0.0195634
# 1.1	0.0256945
# 1.2	0.0328743
# 1.3	0.0411358
# 1.4	0.0504977
# 1.5	0.060964
# 1.6	0.0725234
# 1.7	0.0851499
# 1.8	0.098802
# 1.9	0.113423
# 2	0.128943
# 2.1	0.145277
# 2.2	0.162325
# 2.3	0.179979
# 2.4	0.198115
# 2.5	0.2166
# 2.6	0.235294
# 2.7	0.254045
# 2.8	0.272699
# 2.9	0.291093
# 3	0.309063
# 3.1	0.326443
# 3.2	0.343066
# 3.3	0.358769
# 3.4	0.373389
# 3.5	0.38677
# 3.6	0.398763
# 3.7	0.409225
# 3.8	0.418026
# 3.9	0.425044
# 4	0.430171
# 4.1	0.433315
# 4.2	0.434394
# 4.3	0.433347
# 4.4	0.430127
# 4.5	0.424704
# 4.6	0.417069
# 4.7	0.407228
# 4.8	0.395209
# 4.9	0.381055
# 5	0.364831
# 5.1	0.346619
# 5.2	0.326517
# 5.3	0.304641
# 5.4	0.281126
# 5.5	0.256118
# 5.6	0.229779
# 5.7	0.202284
# 5.8	0.173818
# 5.9	0.144579
# 6	0.114768
# 6.1	0.0845982
# 6.2	0.0542833
# 6.3	0.0240416
# 6.4	-0.00590769
# 6.5	-0.0353466
# 6.6	-0.0640599
# 6.7	-0.091837
# 6.8	-0.118474
# 6.9	-0.143775
# 7	-0.167556
# 7.1	-0.189641
# 7.2	-0.209872
# 7.3	-0.228102
# 7.4	-0.244202
# 7.5	-0.258061
# 7.6	-0.269584
# 7.7	-0.278697
# 7.8	-0.285346
# 7.9	-0.289495
# 8	-0.291132
# 8.1	-0.290264
# 8.2	-0.28692
# 8.3	-0.281148
# 8.4	-0.273017
# 8.5	-0.262616
# 8.6	-0.250053
# 8.7	-0.235454
# 8.8	-0.21896
# 8.9	-0.20073
# 9	-0.180935
# 9.1	-0.159761
# 9.2	-0.137404
# 9.3	-0.114068
# 9.4	-0.0899655
# 9.5	-0.0653153
# 9.6	-0.0403388
# 9.7	-0.0152594
# 9.8	0.0096999
# 9.9	0.0343183
#
# (base) d:\Personal\Estudio\Universidad\Matriculas\Octava matricula\Métodos de Simulación\Clases\Programación Básica (repaso) y Ec. Dif. Ordinarias (3 clases)>

# %%
# %%cmd
# .\Simpson.exe > datos.txt
# Out:
# Microsoft Windows [Versión 10.0.19045.4046]
# (c) Microsoft Corporation. Todos los derechos reservados.
#
# (base) d:\Personal\Estudio\Universidad\Matriculas\Octava matricula\Métodos de Simulación\Clases\Programación Básica (repaso) y Ec. Dif. Ordinarias (3 clases)>.\Simpson.exe > datos.txt
#
# (base) d:\Personal\Estudio\Universidad\Matriculas\Octava matricula\Métodos de Simulación\Clases\Programación Básica (repaso) y Ec. Dif. Ordinarias (3 clases)>

# %%
# %%cmd
# type datos.txt
# Out:
# Microsoft Windows [Versión 10.0.19045.4046]
# (c) Microsoft Corporation. Todos los derechos reservados.
#
# (base) d:\Personal\Estudio\Universidad\Matriculas\Octava matricula\Métodos de Simulación\Clases\Programación Básica (repaso) y Ec. Dif. Ordinarias (3 clases)>type datos.txt
# 0	-2.44249e-17
# 0.1	2.08203e-05
# 0.2	0.00016625
# 0.3	0.000559343
# 0.4	0.00132005
# 0.5	0.00256373
# 0.6	0.00439966
# 0.7	0.00692965
# 0.8	0.0102468
# 0.9	0.014434
# 1	0.0195634
# 1.1	0.0256945
# 1.2	0.0328743
# 1.3	0.0411358
# 1.4	0.0504977
# 1.5	0.060964
# 1.6	0.0725234
# 1.7	0.0851499
# 1.8	0.098802
# 1.9	0.113423
# 2	0.128943
# 2.1	0.145277
# 2.2	0.162325
# 2.3	0.179979
# 2.4	0.198115
# 2.5	0.2166
# 2.6	0.235294
# 2.7	0.254045
# 2.8	0.272699
# 2.9	0.291093
# 3	0.309063
# 3.1	0.326443
# 3.2	0.343066
# 3.3	0.358769
# 3.4	0.373389
# 3.5	0.38677
# 3.6	0.398763
# 3.7	0.409225
# 3.8	0.418026
# 3.9	0.425044
# 4	0.430171
# 4.1	0.433315
# 4.2	0.434394
# 4.3	0.433347
# 4.4	0.430127
# 4.5	0.424704
# 4.6	0.417069
# 4.7	0.407228
# 4.8	0.395209
# 4.9	0.381055
# 5	0.364831
# 5.1	0.346619
# 5.2	0.326517
# 5.3	0.304641
# 5.4	0.281126
# 5.5	0.256118
# 5.6	0.229779
# 5.7	0.202284
# 5.8	0.173818
# 5.9	0.144579
# 6	0.114768
# 6.1	0.0845982
# 6.2	0.0542833
# 6.3	0.0240416
# 6.4	-0.00590769
# 6.5	-0.0353466
# 6.6	-0.0640599
# 6.7	-0.091837
# 6.8	-0.118474
# 6.9	-0.143775
# 7	-0.167556
# 7.1	-0.189641
# 7.2	-0.209872
# 7.3	-0.228102
# 7.4	-0.244202
# 7.5	-0.258061
# 7.6	-0.269584
# 7.7	-0.278697
# 7.8	-0.285346
# 7.9	-0.289495
# 8	-0.291132
# 8.1	-0.290264
# 8.2	-0.28692
# 8.3	-0.281148
# 8.4	-0.273017
# 8.5	-0.262616
# 8.6	-0.250053
# 8.7	-0.235454
# 8.8	-0.21896
# 8.9	-0.20073
# 9	-0.180935
# 9.1	-0.159761
# 9.2	-0.137404
# 9.3	-0.114068
# 9.4	-0.0899655
# 9.5	-0.0653153
# 9.6	-0.0403388
# 9.7	-0.0152594
# 9.8	0.0096999
# 9.9	0.0343183
#
# (base) d:\Personal\Estudio\Universidad\Matriculas\Octava matricula\Métodos de Simulación\Clases\Programación Básica (repaso) y Ec. Dif. Ordinarias (3 clases)>

# %%
import pandas as pd
import matplotlib.pyplot as plt

def graficar(datos):

    path = "./"+ datos + ".cat"
    data = pd.read_csv(path,sep=' ',names=['t','x1','x2'])

    plt.plot(data['t'],data['x1'],label='x1')

# %%
 graficar("datos")
