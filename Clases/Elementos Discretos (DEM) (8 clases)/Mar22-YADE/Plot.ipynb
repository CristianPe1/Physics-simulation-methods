# %%
pip install yade
# Out:
# ...
#   Obtaining dependency information for yade from https://files.pythonhosted.org/packages/f3/bd/8b4004170efcf9eb7483e660a94c72417fba6ed220d708c25a69b09f48b0/yade-0.1.3-py2.py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from yade import qt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from yade import qt
#
# ImportError: cannot import name 'qt' from 'yade' (c:\Users\cterr\anaconda3\Lib\site-packages\yade\__init__.py)
